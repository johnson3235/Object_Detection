# %%
import cv2
import os
import numpy as np
from sklearn import metrics
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, accuracy_score
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from keras.applications.vgg16 import VGG16
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
#import matplotlib.pyplot as plt    

data_path = r"D:\BasicTraining (1)\train"
img_size=256             
counter=0            
X=[]
Y=[]

# %%
categories=os.listdir(data_path)
 
for category in categories:                                                            
    folder_path=os.path.join(data_path,category)                                       
    img_names=os.listdir(folder_path)                                                  
 
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        fullpath=os.path.join(data_path,category,img_name)
        try:
            img = cv2.imread(fullpath, cv2.IMREAD_COLOR)
            img = cv2.resize(img, (img_size,img_size))
            img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
            X.append(img)
            Y.append(category)
            counter+=1
            print("Reprocessing Image Number: ",counter)
        except:
            print("Error in Image Number ==> ",counter)
 
imgs=np.array(X)
lbls=np.array(Y)
# Out:
# Reprocessing Image Number:  1
# Reprocessing Image Number:  2
# Reprocessing Image Number:  3
# Reprocessing Image Number:  4
# Reprocessing Image Number:  5
# Reprocessing Image Number:  6
# Reprocessing Image Number:  7
# Reprocessing Image Number:  8
# Reprocessing Image Number:  9
# Reprocessing Image Number:  10
# Reprocessing Image Number:  11
# Reprocessing Image Number:  12
# Reprocessing Image Number:  13
# Reprocessing Image Number:  14
# Reprocessing Image Number:  15
# Reprocessing Image Number:  16
# Reprocessing Image Number:  17
# Reprocessing Image Number:  18
# Reprocessing Image Number:  19
# Reprocessing Image Number:  20
# Reprocessing Image Number:  21
# Reprocessing Image Number:  22
# Reprocessing Image Number:  23
# Reprocessing Image Number:  24
# Reprocessing Image Number:  25
# Reprocessing Image Number:  26
# Reprocessing Image Number:  27
# Reprocessing Image Number:  28
# Reprocessing Image Number:  29
# Reprocessing Image Number:  30
# Reprocessing Image Number:  31
# Reprocessing Image Number:  32
# Reprocessing Image Number:  33
# Reprocessing Image Number:  34
# Reprocessing Image Number:  35
# Reprocessing Image Number:  36
# Reprocessing Image Number:  37
# Reprocessing Image Number:  38
# Reprocessing Image Number:  39
# Reprocessing Image Number:  40
# Reprocessing Image Number:  41
# Reprocessing Image Number:  42
# Reprocessing Image Number:  43
# Reprocessing Image Number:  44
# Reprocessing Image Number:  45
# Reprocessing Image Number:  46
# Reprocessing Image Number:  47
# Reprocessing Image Number:  48
# Reprocessing Image Number:  49
# Reprocessing Image Number:  50
# Reprocessing Image Number:  51
# Reprocessing Image Number:  52
# Reprocessing Image Number:  53
# Reprocessing Image Number:  54
# Reprocessing Image Number:  55
# Reprocessing Image Number:  56
# Reprocessing Image Number:  57
# Reprocessing Image Number:  58
# Reprocessing Image Number:  59
# Reprocessing Image Number:  60
# Reprocessing Image Number:  61
# Reprocessing Image Number:  62
# Reprocessing Image Number:  63
# Reprocessing Image Number:  64
# Reprocessing Image Number:  65
# Reprocessing Image Number:  66
# Reprocessing Image Number:  67
# Reprocessing Image Number:  68
# Reprocessing Image Number:  69
# Reprocessing Image Number:  70
# Reprocessing Image Number:  71
# Reprocessing Image Number:  72
# Reprocessing Image Number:  73
# Reprocessing Image Number:  74
# Reprocessing Image Number:  75
# Reprocessing Image Number:  76
# Reprocessing Image Number:  77
# Reprocessing Image Number:  78
# Reprocessing Image Number:  79
# Reprocessing Image Number:  80
# Reprocessing Image Number:  81
# Reprocessing Image Number:  82
# Reprocessing Image Number:  83
# Reprocessing Image Number:  84
# Reprocessing Image Number:  85
# Reprocessing Image Number:  86
# Reprocessing Image Number:  87
# Reprocessing Image Number:  88
# Reprocessing Image Number:  89
# Reprocessing Image Number:  90
# Reprocessing Image Number:  91
# Reprocessing Image Number:  92
# Reprocessing Image Number:  93
# Reprocessing Image Number:  94
# Reprocessing Image Number:  95
# Reprocessing Image Number:  96
# Reprocessing Image Number:  97
# Reprocessing Image Number:  98
# Reprocessing Image Number:  99
# Reprocessing Image Number:  100
# Reprocessing Image Number:  101
# Reprocessing Image Number:  102
# Reprocessing Image Number:  103
# Reprocessing Image Number:  104
# Reprocessing Image Number:  105
# Reprocessing Image Number:  106
# Reprocessing Image Number:  107
# Reprocessing Image Number:  108
# Reprocessing Image Number:  109
# Reprocessing Image Number:  110
# Reprocessing Image Number:  111
# Reprocessing Image Number:  112
# Reprocessing Image Number:  113
# Reprocessing Image Number:  114
# Reprocessing Image Number:  115
# Reprocessing Image Number:  116
# Reprocessing Image Number:  117
# Reprocessing Image Number:  118
# Reprocessing Image Number:  119
# Reprocessing Image Number:  120
# Reprocessing Image Number:  121
# Reprocessing Image Number:  122
# Reprocessing Image Number:  123
# Reprocessing Image Number:  124
# Reprocessing Image Number:  125
# Reprocessing Image Number:  126
# Reprocessing Image Number:  127
# Reprocessing Image Number:  128
# Reprocessing Image Number:  129
# Reprocessing Image Number:  130
# Reprocessing Image Number:  131
# Reprocessing Image Number:  132
# Reprocessing Image Number:  133
# Reprocessing Image Number:  134
# Reprocessing Image Number:  135
# Reprocessing Image Number:  136
# Reprocessing Image Number:  137
# Reprocessing Image Number:  138
# Reprocessing Image Number:  139
# Reprocessing Image Number:  140
# Reprocessing Image Number:  141
# Reprocessing Image Number:  142
# Reprocessing Image Number:  143
# Reprocessing Image Number:  144
# Reprocessing Image Number:  145
# Reprocessing Image Number:  146
# Reprocessing Image Number:  147
# Reprocessing Image Number:  148
# Reprocessing Image Number:  149
# Reprocessing Image Number:  150
# Reprocessing Image Number:  151
# Reprocessing Image Number:  152
# Reprocessing Image Number:  153
# Reprocessing Image Number:  154
# Reprocessing Image Number:  155
# Reprocessing Image Number:  156
# Reprocessing Image Number:  157
# Reprocessing Image Number:  158
# Reprocessing Image Number:  159
# Reprocessing Image Number:  160
# Reprocessing Image Number:  161
# Reprocessing Image Number:  162
# Reprocessing Image Number:  163
# Reprocessing Image Number:  164
# Reprocessing Image Number:  165
# Reprocessing Image Number:  166
# Reprocessing Image Number:  167
# Reprocessing Image Number:  168
# Reprocessing Image Number:  169
# Reprocessing Image Number:  170
# Reprocessing Image Number:  171
# Reprocessing Image Number:  172
# Reprocessing Image Number:  173
# Reprocessing Image Number:  174
# Reprocessing Image Number:  175
# Reprocessing Image Number:  176
# Reprocessing Image Number:  177
# Reprocessing Image Number:  178
# Reprocessing Image Number:  179
# Reprocessing Image Number:  180
# Reprocessing Image Number:  181
# Reprocessing Image Number:  182
# Reprocessing Image Number:  183
# Reprocessing Image Number:  184
# Reprocessing Image Number:  185
# Reprocessing Image Number:  186
# Reprocessing Image Number:  187
# Reprocessing Image Number:  188
# Reprocessing Image Number:  189
# Reprocessing Image Number:  190
# Reprocessing Image Number:  191
# Reprocessing Image Number:  192
# Reprocessing Image Number:  193
# Reprocessing Image Number:  194
# Reprocessing Image Number:  195
# Reprocessing Image Number:  196
# Reprocessing Image Number:  197
# Reprocessing Image Number:  198
# Reprocessing Image Number:  199
# Reprocessing Image Number:  200
# Reprocessing Image Number:  201
# Reprocessing Image Number:  202
# Reprocessing Image Number:  203
# Reprocessing Image Number:  204
# Reprocessing Image Number:  205
# Reprocessing Image Number:  206
# Reprocessing Image Number:  207
# Reprocessing Image Number:  208
# Reprocessing Image Number:  209
# Reprocessing Image Number:  210
# Reprocessing Image Number:  211
# Reprocessing Image Number:  212
# Reprocessing Image Number:  213
# Reprocessing Image Number:  214
# Reprocessing Image Number:  215
# Reprocessing Image Number:  216
# Reprocessing Image Number:  217
# Reprocessing Image Number:  218
# Reprocessing Image Number:  219
# Reprocessing Image Number:  220
# Reprocessing Image Number:  221
# Reprocessing Image Number:  222
# Reprocessing Image Number:  223
# Reprocessing Image Number:  224
# Reprocessing Image Number:  225
# Reprocessing Image Number:  226
# Reprocessing Image Number:  227
# Reprocessing Image Number:  228
# Reprocessing Image Number:  229
# Reprocessing Image Number:  230
# Reprocessing Image Number:  231
# Reprocessing Image Number:  232
# Reprocessing Image Number:  233
# Reprocessing Image Number:  234
# Reprocessing Image Number:  235
# Reprocessing Image Number:  236
# Reprocessing Image Number:  237
# Reprocessing Image Number:  238
# Reprocessing Image Number:  239
# Reprocessing Image Number:  240
# Reprocessing Image Number:  241
# Reprocessing Image Number:  242
# Reprocessing Image Number:  243
# Reprocessing Image Number:  244
# Reprocessing Image Number:  245
# Reprocessing Image Number:  246
# Reprocessing Image Number:  247
# Reprocessing Image Number:  248
# Reprocessing Image Number:  249
# Reprocessing Image Number:  250
# Reprocessing Image Number:  251
# Reprocessing Image Number:  252
# Reprocessing Image Number:  253
# Reprocessing Image Number:  254
# Reprocessing Image Number:  255
# Reprocessing Image Number:  256
# Reprocessing Image Number:  257
# Reprocessing Image Number:  258
# Reprocessing Image Number:  259
# Reprocessing Image Number:  260
# Reprocessing Image Number:  261
# Reprocessing Image Number:  262
# Reprocessing Image Number:  263
# Reprocessing Image Number:  264
# Reprocessing Image Number:  265
# Reprocessing Image Number:  266
# Reprocessing Image Number:  267
# Reprocessing Image Number:  268
# Reprocessing Image Number:  269
# Reprocessing Image Number:  270
# Reprocessing Image Number:  271
# Reprocessing Image Number:  272
# Reprocessing Image Number:  273
# Reprocessing Image Number:  274
# Reprocessing Image Number:  275
# Reprocessing Image Number:  276
# Reprocessing Image Number:  277
# Reprocessing Image Number:  278
# Reprocessing Image Number:  279
# Reprocessing Image Number:  280
# Reprocessing Image Number:  281
# Reprocessing Image Number:  282
# Reprocessing Image Number:  283
# Reprocessing Image Number:  284
# Reprocessing Image Number:  285
# Reprocessing Image Number:  286
# Reprocessing Image Number:  287
# Reprocessing Image Number:  288
# Reprocessing Image Number:  289
# Reprocessing Image Number:  290
# Reprocessing Image Number:  291
# Reprocessing Image Number:  292
# Reprocessing Image Number:  293
# Reprocessing Image Number:  294
# Reprocessing Image Number:  295
# Reprocessing Image Number:  296
# Reprocessing Image Number:  297
# Reprocessing Image Number:  298
# Reprocessing Image Number:  299
# Reprocessing Image Number:  300
# Reprocessing Image Number:  301
# Reprocessing Image Number:  302
# Reprocessing Image Number:  303
# Reprocessing Image Number:  304
# Reprocessing Image Number:  305
# Reprocessing Image Number:  306
# Reprocessing Image Number:  307
# Reprocessing Image Number:  308
# Reprocessing Image Number:  309
# Reprocessing Image Number:  310
# Reprocessing Image Number:  311
# Reprocessing Image Number:  312
# Reprocessing Image Number:  313
# Reprocessing Image Number:  314
# Reprocessing Image Number:  315
# Reprocessing Image Number:  316
# Reprocessing Image Number:  317
# Reprocessing Image Number:  318
# Reprocessing Image Number:  319
# Reprocessing Image Number:  320
# Reprocessing Image Number:  321
# Reprocessing Image Number:  322
# Reprocessing Image Number:  323
# Reprocessing Image Number:  324
# Reprocessing Image Number:  325
# Reprocessing Image Number:  326
# Reprocessing Image Number:  327
# Reprocessing Image Number:  328
# Reprocessing Image Number:  329
# Reprocessing Image Number:  330
# Reprocessing Image Number:  331
# Reprocessing Image Number:  332
# Reprocessing Image Number:  333
# Reprocessing Image Number:  334
# Reprocessing Image Number:  335
# Reprocessing Image Number:  336
# Reprocessing Image Number:  337
# Reprocessing Image Number:  338
# Reprocessing Image Number:  339
# Reprocessing Image Number:  340
# Reprocessing Image Number:  341
# Reprocessing Image Number:  342
# Reprocessing Image Number:  343
# Reprocessing Image Number:  344
# Reprocessing Image Number:  345
# Reprocessing Image Number:  346
# Reprocessing Image Number:  347
# Reprocessing Image Number:  348
# Reprocessing Image Number:  349
# Reprocessing Image Number:  350
# Reprocessing Image Number:  351
# Reprocessing Image Number:  352
# Reprocessing Image Number:  353
# Reprocessing Image Number:  354
# Reprocessing Image Number:  355
# Reprocessing Image Number:  356
# Reprocessing Image Number:  357
# Reprocessing Image Number:  358
# Reprocessing Image Number:  359
# Reprocessing Image Number:  360
# Reprocessing Image Number:  361
# Reprocessing Image Number:  362
# Reprocessing Image Number:  363
# Reprocessing Image Number:  364
# Reprocessing Image Number:  365
# Reprocessing Image Number:  366
# Reprocessing Image Number:  367
# Reprocessing Image Number:  368
# Reprocessing Image Number:  369
# Reprocessing Image Number:  370
# Reprocessing Image Number:  371
# Reprocessing Image Number:  372
# Reprocessing Image Number:  373
# Reprocessing Image Number:  374
# Reprocessing Image Number:  375
# Reprocessing Image Number:  376
# Reprocessing Image Number:  377
# Reprocessing Image Number:  378
# Reprocessing Image Number:  379
# Reprocessing Image Number:  380
# Reprocessing Image Number:  381
# Reprocessing Image Number:  382
# Reprocessing Image Number:  383
# Reprocessing Image Number:  384
# Reprocessing Image Number:  385
# Reprocessing Image Number:  386
# Reprocessing Image Number:  387
# Reprocessing Image Number:  388
# Reprocessing Image Number:  389
# Reprocessing Image Number:  390
# Reprocessing Image Number:  391
# Reprocessing Image Number:  392
# Reprocessing Image Number:  393
# Reprocessing Image Number:  394
# Reprocessing Image Number:  395
# Reprocessing Image Number:  396
# Reprocessing Image Number:  397
# Reprocessing Image Number:  398
# Reprocessing Image Number:  399
# Reprocessing Image Number:  400
# Reprocessing Image Number:  401
# Reprocessing Image Number:  402
# Reprocessing Image Number:  403
# Reprocessing Image Number:  404
# Reprocessing Image Number:  405
# Reprocessing Image Number:  406
# Reprocessing Image Number:  407
# Reprocessing Image Number:  408
# Reprocessing Image Number:  409
# Reprocessing Image Number:  410
# Reprocessing Image Number:  411
# Reprocessing Image Number:  412
# Reprocessing Image Number:  413
# Reprocessing Image Number:  414
# Reprocessing Image Number:  415
# Reprocessing Image Number:  416
# Reprocessing Image Number:  417
# Reprocessing Image Number:  418
# Reprocessing Image Number:  419
# Reprocessing Image Number:  420
# Reprocessing Image Number:  421
# Reprocessing Image Number:  422
# Reprocessing Image Number:  423
# Reprocessing Image Number:  424
# Reprocessing Image Number:  425
# Reprocessing Image Number:  426
# Reprocessing Image Number:  427
# Reprocessing Image Number:  428
# Reprocessing Image Number:  429
# Reprocessing Image Number:  430
# Reprocessing Image Number:  431
# Reprocessing Image Number:  432
# Reprocessing Image Number:  433
# Reprocessing Image Number:  434
# Reprocessing Image Number:  435
# Reprocessing Image Number:  436
# Reprocessing Image Number:  437
# Reprocessing Image Number:  438
# Reprocessing Image Number:  439
# Reprocessing Image Number:  440
# Reprocessing Image Number:  441
# Reprocessing Image Number:  442
# Reprocessing Image Number:  443
# Reprocessing Image Number:  444
# Reprocessing Image Number:  445
# Reprocessing Image Number:  446
# Reprocessing Image Number:  447
# Reprocessing Image Number:  448
# Reprocessing Image Number:  449
# Reprocessing Image Number:  450
# Reprocessing Image Number:  451
# Reprocessing Image Number:  452
# Reprocessing Image Number:  453
# Reprocessing Image Number:  454
# Reprocessing Image Number:  455
# Reprocessing Image Number:  456
# Reprocessing Image Number:  457
# Reprocessing Image Number:  458
# Reprocessing Image Number:  459
# Reprocessing Image Number:  460
# Reprocessing Image Number:  461
# Reprocessing Image Number:  462
# Reprocessing Image Number:  463
# Reprocessing Image Number:  464
# Reprocessing Image Number:  465
# Reprocessing Image Number:  466
# Reprocessing Image Number:  467
# Reprocessing Image Number:  468
# Reprocessing Image Number:  469
# Reprocessing Image Number:  470
# Reprocessing Image Number:  471
# Reprocessing Image Number:  472
# Reprocessing Image Number:  473
# Reprocessing Image Number:  474
# Reprocessing Image Number:  475
# Reprocessing Image Number:  476
# Reprocessing Image Number:  477
# Reprocessing Image Number:  478
# Reprocessing Image Number:  479
# Reprocessing Image Number:  480
# Reprocessing Image Number:  481
# Reprocessing Image Number:  482
# Reprocessing Image Number:  483
# Reprocessing Image Number:  484
# Reprocessing Image Number:  485
# Reprocessing Image Number:  486
# Reprocessing Image Number:  487
# Reprocessing Image Number:  488
# Reprocessing Image Number:  489
# Reprocessing Image Number:  490
# Reprocessing Image Number:  491
# Reprocessing Image Number:  492
# Reprocessing Image Number:  493
# Reprocessing Image Number:  494
# Reprocessing Image Number:  495
# Reprocessing Image Number:  496
# Reprocessing Image Number:  497
# Reprocessing Image Number:  498
# Reprocessing Image Number:  499
# Reprocessing Image Number:  500
# Reprocessing Image Number:  501
# Reprocessing Image Number:  502
# Reprocessing Image Number:  503
# Reprocessing Image Number:  504
# Reprocessing Image Number:  505
# Reprocessing Image Number:  506
# Reprocessing Image Number:  507
# Reprocessing Image Number:  508
# Reprocessing Image Number:  509
# Reprocessing Image Number:  510
# Reprocessing Image Number:  511
# Reprocessing Image Number:  512
# Reprocessing Image Number:  513
# Reprocessing Image Number:  514
# Reprocessing Image Number:  515
# Reprocessing Image Number:  516
# Reprocessing Image Number:  517
# Reprocessing Image Number:  518
# Reprocessing Image Number:  519
# Reprocessing Image Number:  520
# Reprocessing Image Number:  521
# Reprocessing Image Number:  522
# Reprocessing Image Number:  523
# Reprocessing Image Number:  524
# Reprocessing Image Number:  525
# Reprocessing Image Number:  526
# Reprocessing Image Number:  527
# Reprocessing Image Number:  528
# Reprocessing Image Number:  529
# Reprocessing Image Number:  530
# Reprocessing Image Number:  531
# Reprocessing Image Number:  532
# Reprocessing Image Number:  533
# Reprocessing Image Number:  534
# Reprocessing Image Number:  535
# Reprocessing Image Number:  536
# Reprocessing Image Number:  537
# Reprocessing Image Number:  538
# Reprocessing Image Number:  539
# Reprocessing Image Number:  540
# Reprocessing Image Number:  541
# Reprocessing Image Number:  542
# Reprocessing Image Number:  543
# Reprocessing Image Number:  544
# Reprocessing Image Number:  545
# Reprocessing Image Number:  546
# Reprocessing Image Number:  547
# Reprocessing Image Number:  548
# Reprocessing Image Number:  549
# Reprocessing Image Number:  550
# Reprocessing Image Number:  551
# Reprocessing Image Number:  552
# Reprocessing Image Number:  553
# Reprocessing Image Number:  554
# Reprocessing Image Number:  555
# Reprocessing Image Number:  556
# Reprocessing Image Number:  557
# Reprocessing Image Number:  558
# Reprocessing Image Number:  559
# Reprocessing Image Number:  560
# Reprocessing Image Number:  561
# Reprocessing Image Number:  562
# Reprocessing Image Number:  563
# Reprocessing Image Number:  564
# Reprocessing Image Number:  565
# Reprocessing Image Number:  566
# Reprocessing Image Number:  567
# Reprocessing Image Number:  568
# Reprocessing Image Number:  569
# Reprocessing Image Number:  570
# Reprocessing Image Number:  571
# Reprocessing Image Number:  572
# Reprocessing Image Number:  573
# Reprocessing Image Number:  574
# Reprocessing Image Number:  575
# Reprocessing Image Number:  576
# Reprocessing Image Number:  577
# Reprocessing Image Number:  578
# Reprocessing Image Number:  579
# Reprocessing Image Number:  580
# Reprocessing Image Number:  581
# Reprocessing Image Number:  582
# Reprocessing Image Number:  583
# Reprocessing Image Number:  584
# Reprocessing Image Number:  585
# Reprocessing Image Number:  586
# Reprocessing Image Number:  587
# Reprocessing Image Number:  588
# Reprocessing Image Number:  589
# Reprocessing Image Number:  590
# Reprocessing Image Number:  591
# Reprocessing Image Number:  592
# Reprocessing Image Number:  593
# Reprocessing Image Number:  594
# Reprocessing Image Number:  595
# Reprocessing Image Number:  596
# Reprocessing Image Number:  597
# Reprocessing Image Number:  598
# Reprocessing Image Number:  599
# Reprocessing Image Number:  600
# Reprocessing Image Number:  601
# Reprocessing Image Number:  602
# Reprocessing Image Number:  603
# Reprocessing Image Number:  604
# Reprocessing Image Number:  605
# Reprocessing Image Number:  606
# Reprocessing Image Number:  607
# Reprocessing Image Number:  608
# Reprocessing Image Number:  609
# Reprocessing Image Number:  610
# Reprocessing Image Number:  611
# Reprocessing Image Number:  612
# Reprocessing Image Number:  613
# Reprocessing Image Number:  614
# Reprocessing Image Number:  615
# Reprocessing Image Number:  616
# Reprocessing Image Number:  617
# Reprocessing Image Number:  618
# Reprocessing Image Number:  619
# Reprocessing Image Number:  620
# Reprocessing Image Number:  621
# Reprocessing Image Number:  622
# Reprocessing Image Number:  623
# Reprocessing Image Number:  624
# Reprocessing Image Number:  625
# Reprocessing Image Number:  626
# Reprocessing Image Number:  627
# Reprocessing Image Number:  628
# Reprocessing Image Number:  629
# Reprocessing Image Number:  630
# Reprocessing Image Number:  631
# Reprocessing Image Number:  632
# Reprocessing Image Number:  633
# Reprocessing Image Number:  634
# Reprocessing Image Number:  635
# Reprocessing Image Number:  636
# Reprocessing Image Number:  637
# Reprocessing Image Number:  638
# Reprocessing Image Number:  639
# Reprocessing Image Number:  640
# Reprocessing Image Number:  641
# Reprocessing Image Number:  642
# Reprocessing Image Number:  643
# Reprocessing Image Number:  644
# Reprocessing Image Number:  645
# Reprocessing Image Number:  646
# Reprocessing Image Number:  647
# Reprocessing Image Number:  648
# Reprocessing Image Number:  649
# Reprocessing Image Number:  650
# Reprocessing Image Number:  651
# Reprocessing Image Number:  652
# Reprocessing Image Number:  653
# Reprocessing Image Number:  654
# Reprocessing Image Number:  655
# Reprocessing Image Number:  656
# Reprocessing Image Number:  657
# Reprocessing Image Number:  658
# Reprocessing Image Number:  659
# Reprocessing Image Number:  660
# Reprocessing Image Number:  661
# Reprocessing Image Number:  662
# Reprocessing Image Number:  663
# Reprocessing Image Number:  664
# Reprocessing Image Number:  665
# Reprocessing Image Number:  666
# Reprocessing Image Number:  667
# Reprocessing Image Number:  668
# Reprocessing Image Number:  669
# Reprocessing Image Number:  670
# Reprocessing Image Number:  671
# Reprocessing Image Number:  672
# Reprocessing Image Number:  673
# Reprocessing Image Number:  674
# Reprocessing Image Number:  675
# Reprocessing Image Number:  676
# Reprocessing Image Number:  677
# Reprocessing Image Number:  678
# Reprocessing Image Number:  679
# Reprocessing Image Number:  680
# Reprocessing Image Number:  681
# Reprocessing Image Number:  682
# Reprocessing Image Number:  683
# Reprocessing Image Number:  684
# Reprocessing Image Number:  685
# Reprocessing Image Number:  686
# Reprocessing Image Number:  687
# Reprocessing Image Number:  688
# Reprocessing Image Number:  689
# Reprocessing Image Number:  690
# Reprocessing Image Number:  691
# Reprocessing Image Number:  692
# Reprocessing Image Number:  693
# Reprocessing Image Number:  694
# Reprocessing Image Number:  695
# Reprocessing Image Number:  696
# Reprocessing Image Number:  697
# Reprocessing Image Number:  698
# Reprocessing Image Number:  699
# Reprocessing Image Number:  700
# Reprocessing Image Number:  701
# Reprocessing Image Number:  702
# Reprocessing Image Number:  703
# Reprocessing Image Number:  704
# Reprocessing Image Number:  705
# Reprocessing Image Number:  706
# Reprocessing Image Number:  707
# Reprocessing Image Number:  708
# Reprocessing Image Number:  709
# Reprocessing Image Number:  710
# Reprocessing Image Number:  711
# Reprocessing Image Number:  712
# Reprocessing Image Number:  713
# Reprocessing Image Number:  714
# Reprocessing Image Number:  715
# Reprocessing Image Number:  716
# Reprocessing Image Number:  717
# Reprocessing Image Number:  718
# Reprocessing Image Number:  719
# Reprocessing Image Number:  720
# Reprocessing Image Number:  721
# Reprocessing Image Number:  722
# Reprocessing Image Number:  723
# Reprocessing Image Number:  724
# Reprocessing Image Number:  725
# Reprocessing Image Number:  726
# Reprocessing Image Number:  727
# Reprocessing Image Number:  728
# Reprocessing Image Number:  729
# Reprocessing Image Number:  730
# Reprocessing Image Number:  731
# Reprocessing Image Number:  732
# Reprocessing Image Number:  733
# Reprocessing Image Number:  734
# Reprocessing Image Number:  735
# Reprocessing Image Number:  736
# Reprocessing Image Number:  737
# Reprocessing Image Number:  738
# Reprocessing Image Number:  739
# Reprocessing Image Number:  740
# Reprocessing Image Number:  741
# Reprocessing Image Number:  742
# Reprocessing Image Number:  743
# Reprocessing Image Number:  744
# Reprocessing Image Number:  745
# Reprocessing Image Number:  746
# Reprocessing Image Number:  747
# Reprocessing Image Number:  748
# Reprocessing Image Number:  749
# Reprocessing Image Number:  750
# Reprocessing Image Number:  751
# Reprocessing Image Number:  752
# Reprocessing Image Number:  753
# Reprocessing Image Number:  754
# Reprocessing Image Number:  755
# Reprocessing Image Number:  756
# Reprocessing Image Number:  757
# Reprocessing Image Number:  758
# Reprocessing Image Number:  759
# Reprocessing Image Number:  760
# Reprocessing Image Number:  761
# Reprocessing Image Number:  762
# Reprocessing Image Number:  763
# Reprocessing Image Number:  764
# Reprocessing Image Number:  765
# Reprocessing Image Number:  766
# Reprocessing Image Number:  767
# Reprocessing Image Number:  768
# Reprocessing Image Number:  769
# Reprocessing Image Number:  770
# Reprocessing Image Number:  771
# Reprocessing Image Number:  772
# Reprocessing Image Number:  773
# Reprocessing Image Number:  774
# Reprocessing Image Number:  775
# Reprocessing Image Number:  776
# Reprocessing Image Number:  777
# Reprocessing Image Number:  778
# Reprocessing Image Number:  779
# Reprocessing Image Number:  780
# Reprocessing Image Number:  781
# Reprocessing Image Number:  782
# Reprocessing Image Number:  783
# Reprocessing Image Number:  784
# Reprocessing Image Number:  785
# Reprocessing Image Number:  786
# Reprocessing Image Number:  787
# Reprocessing Image Number:  788
# Reprocessing Image Number:  789
# Reprocessing Image Number:  790
# Reprocessing Image Number:  791
# Reprocessing Image Number:  792
# Reprocessing Image Number:  793
# Reprocessing Image Number:  794
# Reprocessing Image Number:  795
# Reprocessing Image Number:  796
# Reprocessing Image Number:  797
# Reprocessing Image Number:  798
# Reprocessing Image Number:  799
# Reprocessing Image Number:  800
# Reprocessing Image Number:  801
# Reprocessing Image Number:  802
# Reprocessing Image Number:  803
# Reprocessing Image Number:  804
# Reprocessing Image Number:  805
# Reprocessing Image Number:  806
# Reprocessing Image Number:  807
# Reprocessing Image Number:  808
# Reprocessing Image Number:  809
# Reprocessing Image Number:  810
# Reprocessing Image Number:  811
# Reprocessing Image Number:  812
# Reprocessing Image Number:  813
# Reprocessing Image Number:  814
# Reprocessing Image Number:  815
# Reprocessing Image Number:  816
# Reprocessing Image Number:  817
# Reprocessing Image Number:  818
# Reprocessing Image Number:  819
# Reprocessing Image Number:  820
# Reprocessing Image Number:  821
# Reprocessing Image Number:  822
# Reprocessing Image Number:  823
# Reprocessing Image Number:  824
# Reprocessing Image Number:  825
# Reprocessing Image Number:  826
# Reprocessing Image Number:  827
# Reprocessing Image Number:  828
# Reprocessing Image Number:  829
# Reprocessing Image Number:  830
# Reprocessing Image Number:  831
# Reprocessing Image Number:  832
# Reprocessing Image Number:  833
# Reprocessing Image Number:  834
# Reprocessing Image Number:  835
# Reprocessing Image Number:  836
# Reprocessing Image Number:  837
# Reprocessing Image Number:  838
# Reprocessing Image Number:  839
# Reprocessing Image Number:  840
# Reprocessing Image Number:  841
# Reprocessing Image Number:  842
# Reprocessing Image Number:  843
# Reprocessing Image Number:  844
# Reprocessing Image Number:  845
# Reprocessing Image Number:  846
# Reprocessing Image Number:  847
# Reprocessing Image Number:  848
# Reprocessing Image Number:  849
# Reprocessing Image Number:  850
# Reprocessing Image Number:  851
# Reprocessing Image Number:  852
# Reprocessing Image Number:  853
# Reprocessing Image Number:  854
# Reprocessing Image Number:  855
# Reprocessing Image Number:  856
# Reprocessing Image Number:  857
# Reprocessing Image Number:  858
# Reprocessing Image Number:  859
# Reprocessing Image Number:  860
# Reprocessing Image Number:  861
# Reprocessing Image Number:  862
# Reprocessing Image Number:  863
# Reprocessing Image Number:  864
# Reprocessing Image Number:  865
# Reprocessing Image Number:  866
# Reprocessing Image Number:  867
# Reprocessing Image Number:  868
# Reprocessing Image Number:  869
# Reprocessing Image Number:  870
# Reprocessing Image Number:  871
# Reprocessing Image Number:  872
# Reprocessing Image Number:  873
# Reprocessing Image Number:  874
# Reprocessing Image Number:  875
# Reprocessing Image Number:  876
# Reprocessing Image Number:  877
# Reprocessing Image Number:  878
# Reprocessing Image Number:  879
# Reprocessing Image Number:  880
# Reprocessing Image Number:  881
# Reprocessing Image Number:  882
# Reprocessing Image Number:  883
# Reprocessing Image Number:  884
# Reprocessing Image Number:  885
# Reprocessing Image Number:  886
# Reprocessing Image Number:  887
# Reprocessing Image Number:  888
# Reprocessing Image Number:  889
# Reprocessing Image Number:  890
# Reprocessing Image Number:  891
# Reprocessing Image Number:  892
# Reprocessing Image Number:  893
# Reprocessing Image Number:  894
# Reprocessing Image Number:  895
# Reprocessing Image Number:  896
# Reprocessing Image Number:  897
# Reprocessing Image Number:  898
# Reprocessing Image Number:  899
# Reprocessing Image Number:  900
# Reprocessing Image Number:  901
# Reprocessing Image Number:  902
# Reprocessing Image Number:  903
# Reprocessing Image Number:  904
# Reprocessing Image Number:  905
# Reprocessing Image Number:  906
# Reprocessing Image Number:  907
# Reprocessing Image Number:  908
# Reprocessing Image Number:  909
# Reprocessing Image Number:  910
# Reprocessing Image Number:  911
# Reprocessing Image Number:  912
# Reprocessing Image Number:  913
# Reprocessing Image Number:  914
# Reprocessing Image Number:  915
# Reprocessing Image Number:  916
# Reprocessing Image Number:  917
# Reprocessing Image Number:  918
# Reprocessing Image Number:  919
# Reprocessing Image Number:  920
# Reprocessing Image Number:  921
# Reprocessing Image Number:  922
# Reprocessing Image Number:  923
# Reprocessing Image Number:  924
# Reprocessing Image Number:  925
# Reprocessing Image Number:  926
# Reprocessing Image Number:  927
# Reprocessing Image Number:  928
# Reprocessing Image Number:  929
# Reprocessing Image Number:  930
# Reprocessing Image Number:  931
# Reprocessing Image Number:  932
# Reprocessing Image Number:  933
# Reprocessing Image Number:  934
# Reprocessing Image Number:  935
# Reprocessing Image Number:  936
# Reprocessing Image Number:  937
# Reprocessing Image Number:  938
# Reprocessing Image Number:  939
# Reprocessing Image Number:  940
# Reprocessing Image Number:  941
# Reprocessing Image Number:  942
# Reprocessing Image Number:  943
# Reprocessing Image Number:  944
# Reprocessing Image Number:  945
# Reprocessing Image Number:  946
# Reprocessing Image Number:  947
# Reprocessing Image Number:  948
# Reprocessing Image Number:  949
# Reprocessing Image Number:  950
# Reprocessing Image Number:  951
# Reprocessing Image Number:  952
# Reprocessing Image Number:  953
# Reprocessing Image Number:  954
# Reprocessing Image Number:  955
# Reprocessing Image Number:  956
# Reprocessing Image Number:  957
# Reprocessing Image Number:  958
# Reprocessing Image Number:  959
# Reprocessing Image Number:  960
# Reprocessing Image Number:  961
# Reprocessing Image Number:  962
# Reprocessing Image Number:  963
# Reprocessing Image Number:  964
# Reprocessing Image Number:  965
# Reprocessing Image Number:  966
# Reprocessing Image Number:  967
# Reprocessing Image Number:  968
# Reprocessing Image Number:  969
# Reprocessing Image Number:  970
# Reprocessing Image Number:  971
# Reprocessing Image Number:  972
# Reprocessing Image Number:  973
# Reprocessing Image Number:  974
# Reprocessing Image Number:  975
# Reprocessing Image Number:  976
# Reprocessing Image Number:  977
# Reprocessing Image Number:  978
# Reprocessing Image Number:  979
# Reprocessing Image Number:  980
# Reprocessing Image Number:  981
# Reprocessing Image Number:  982
# Reprocessing Image Number:  983
# Reprocessing Image Number:  984
# Reprocessing Image Number:  985
# Reprocessing Image Number:  986
# Reprocessing Image Number:  987
# Reprocessing Image Number:  988
# Reprocessing Image Number:  989
# Reprocessing Image Number:  990
# Reprocessing Image Number:  991
# Reprocessing Image Number:  992
# Reprocessing Image Number:  993
# Reprocessing Image Number:  994
# Reprocessing Image Number:  995
# Reprocessing Image Number:  996
# Reprocessing Image Number:  997
# Reprocessing Image Number:  998
# Reprocessing Image Number:  999
# Reprocessing Image Number:  1000
# Reprocessing Image Number:  1001
# Reprocessing Image Number:  1002
# Reprocessing Image Number:  1003
# Reprocessing Image Number:  1004
# Reprocessing Image Number:  1005
# Reprocessing Image Number:  1006
# Reprocessing Image Number:  1007
# Reprocessing Image Number:  1008
# Reprocessing Image Number:  1009
# Reprocessing Image Number:  1010
# Reprocessing Image Number:  1011
# Reprocessing Image Number:  1012
# Reprocessing Image Number:  1013
# Reprocessing Image Number:  1014
# Reprocessing Image Number:  1015
# Reprocessing Image Number:  1016
# Reprocessing Image Number:  1017
# Reprocessing Image Number:  1018
# Reprocessing Image Number:  1019
# Reprocessing Image Number:  1020
# Reprocessing Image Number:  1021
# Reprocessing Image Number:  1022
# Reprocessing Image Number:  1023
# Reprocessing Image Number:  1024
# Reprocessing Image Number:  1025
# Reprocessing Image Number:  1026
# Reprocessing Image Number:  1027
# Reprocessing Image Number:  1028
# Reprocessing Image Number:  1029
# Reprocessing Image Number:  1030
# Reprocessing Image Number:  1031
# Reprocessing Image Number:  1032
# Reprocessing Image Number:  1033
# Reprocessing Image Number:  1034
# Reprocessing Image Number:  1035
# Reprocessing Image Number:  1036
# Reprocessing Image Number:  1037
# Reprocessing Image Number:  1038
# Reprocessing Image Number:  1039
# Reprocessing Image Number:  1040
# Reprocessing Image Number:  1041
# Reprocessing Image Number:  1042
# Reprocessing Image Number:  1043
# Reprocessing Image Number:  1044
# Reprocessing Image Number:  1045
# Reprocessing Image Number:  1046
# Reprocessing Image Number:  1047
# Reprocessing Image Number:  1048
# Reprocessing Image Number:  1049
# Reprocessing Image Number:  1050
# Reprocessing Image Number:  1051
# Reprocessing Image Number:  1052
# Reprocessing Image Number:  1053
# Reprocessing Image Number:  1054
# Reprocessing Image Number:  1055
# Reprocessing Image Number:  1056
# Reprocessing Image Number:  1057
# Reprocessing Image Number:  1058
# Reprocessing Image Number:  1059
# Reprocessing Image Number:  1060
# Reprocessing Image Number:  1061
# Reprocessing Image Number:  1062
# Reprocessing Image Number:  1063
# Reprocessing Image Number:  1064
# Reprocessing Image Number:  1065
# Reprocessing Image Number:  1066
# Reprocessing Image Number:  1067
# Reprocessing Image Number:  1068
# Reprocessing Image Number:  1069
# Reprocessing Image Number:  1070
# Reprocessing Image Number:  1071
# Reprocessing Image Number:  1072
# Reprocessing Image Number:  1073
# Reprocessing Image Number:  1074
# Reprocessing Image Number:  1075
# Reprocessing Image Number:  1076
# Reprocessing Image Number:  1077
# Reprocessing Image Number:  1078
# Reprocessing Image Number:  1079
# Reprocessing Image Number:  1080
# Reprocessing Image Number:  1081
# Reprocessing Image Number:  1082
# Reprocessing Image Number:  1083
# Reprocessing Image Number:  1084
# Reprocessing Image Number:  1085
# Reprocessing Image Number:  1086
# Reprocessing Image Number:  1087
# Reprocessing Image Number:  1088
# Reprocessing Image Number:  1089
# Reprocessing Image Number:  1090
# Reprocessing Image Number:  1091
# Reprocessing Image Number:  1092
# Reprocessing Image Number:  1093
# Reprocessing Image Number:  1094
# Reprocessing Image Number:  1095
# Reprocessing Image Number:  1096
# Reprocessing Image Number:  1097
# Reprocessing Image Number:  1098
# Reprocessing Image Number:  1099
# Reprocessing Image Number:  1100
# Reprocessing Image Number:  1101
# Reprocessing Image Number:  1102
# Reprocessing Image Number:  1103
# Reprocessing Image Number:  1104
# Reprocessing Image Number:  1105
# Reprocessing Image Number:  1106
# Reprocessing Image Number:  1107
# Reprocessing Image Number:  1108
# Reprocessing Image Number:  1109
# Reprocessing Image Number:  1110
# Reprocessing Image Number:  1111
# Reprocessing Image Number:  1112
# Reprocessing Image Number:  1113
# Reprocessing Image Number:  1114
# Reprocessing Image Number:  1115
# Reprocessing Image Number:  1116
# Reprocessing Image Number:  1117
# Reprocessing Image Number:  1118
# Reprocessing Image Number:  1119
# Reprocessing Image Number:  1120
# Reprocessing Image Number:  1121
# Reprocessing Image Number:  1122
# Reprocessing Image Number:  1123
# Reprocessing Image Number:  1124
# Reprocessing Image Number:  1125
# Reprocessing Image Number:  1126
# Reprocessing Image Number:  1127
# Reprocessing Image Number:  1128
# Reprocessing Image Number:  1129
# Reprocessing Image Number:  1130
# Reprocessing Image Number:  1131
# Reprocessing Image Number:  1132
# Reprocessing Image Number:  1133
# Reprocessing Image Number:  1134
# Reprocessing Image Number:  1135
# Reprocessing Image Number:  1136
# Reprocessing Image Number:  1137
# Reprocessing Image Number:  1138
# Reprocessing Image Number:  1139
# Reprocessing Image Number:  1140
# Reprocessing Image Number:  1141
# Reprocessing Image Number:  1142
# Reprocessing Image Number:  1143
# Reprocessing Image Number:  1144
# Reprocessing Image Number:  1145
# Reprocessing Image Number:  1146
# Reprocessing Image Number:  1147
# Reprocessing Image Number:  1148
# Reprocessing Image Number:  1149
# Reprocessing Image Number:  1150
# Reprocessing Image Number:  1151
# Reprocessing Image Number:  1152
# Reprocessing Image Number:  1153
# Reprocessing Image Number:  1154
# Reprocessing Image Number:  1155
# Reprocessing Image Number:  1156
# Reprocessing Image Number:  1157
# Reprocessing Image Number:  1158
# Reprocessing Image Number:  1159
# Reprocessing Image Number:  1160
# Reprocessing Image Number:  1161
# Reprocessing Image Number:  1162
# Reprocessing Image Number:  1163
# Reprocessing Image Number:  1164
# Reprocessing Image Number:  1165
# Reprocessing Image Number:  1166
# Reprocessing Image Number:  1167
# Reprocessing Image Number:  1168
# Reprocessing Image Number:  1169
# Reprocessing Image Number:  1170
# Reprocessing Image Number:  1171
# Reprocessing Image Number:  1172
# Reprocessing Image Number:  1173
# Reprocessing Image Number:  1174
# Reprocessing Image Number:  1175
# Reprocessing Image Number:  1176
# Reprocessing Image Number:  1177
# Reprocessing Image Number:  1178
# Reprocessing Image Number:  1179
# Reprocessing Image Number:  1180
# Reprocessing Image Number:  1181
# Reprocessing Image Number:  1182
# Reprocessing Image Number:  1183
# Reprocessing Image Number:  1184
# Reprocessing Image Number:  1185
# Reprocessing Image Number:  1186
# Reprocessing Image Number:  1187
# Reprocessing Image Number:  1188
# Reprocessing Image Number:  1189
# Reprocessing Image Number:  1190
# Reprocessing Image Number:  1191
# Reprocessing Image Number:  1192
# Reprocessing Image Number:  1193
# Reprocessing Image Number:  1194
# Reprocessing Image Number:  1195
# Reprocessing Image Number:  1196
# Reprocessing Image Number:  1197
# Reprocessing Image Number:  1198
# Reprocessing Image Number:  1199
# Reprocessing Image Number:  1200
# Reprocessing Image Number:  1201
# Reprocessing Image Number:  1202
# Reprocessing Image Number:  1203
# Reprocessing Image Number:  1204
# Reprocessing Image Number:  1205
# Reprocessing Image Number:  1206
# Reprocessing Image Number:  1207
# Reprocessing Image Number:  1208
# Reprocessing Image Number:  1209
# Reprocessing Image Number:  1210
# Reprocessing Image Number:  1211
# Reprocessing Image Number:  1212
# Reprocessing Image Number:  1213
# Reprocessing Image Number:  1214
# Reprocessing Image Number:  1215
# Reprocessing Image Number:  1216
# Reprocessing Image Number:  1217
# Reprocessing Image Number:  1218
# Reprocessing Image Number:  1219
# Reprocessing Image Number:  1220
# Reprocessing Image Number:  1221
# Reprocessing Image Number:  1222
# Reprocessing Image Number:  1223
# Reprocessing Image Number:  1224
# Reprocessing Image Number:  1225
# Reprocessing Image Number:  1226
# Reprocessing Image Number:  1227
# Reprocessing Image Number:  1228
# Reprocessing Image Number:  1229
# Reprocessing Image Number:  1230
# Reprocessing Image Number:  1231
# Reprocessing Image Number:  1232
# Reprocessing Image Number:  1233
# Reprocessing Image Number:  1234
# Reprocessing Image Number:  1235
# Reprocessing Image Number:  1236
# Reprocessing Image Number:  1237
# Reprocessing Image Number:  1238
# Reprocessing Image Number:  1239
# Reprocessing Image Number:  1240
# Reprocessing Image Number:  1241
# Reprocessing Image Number:  1242
# Reprocessing Image Number:  1243
# Reprocessing Image Number:  1244
# Reprocessing Image Number:  1245
# Reprocessing Image Number:  1246
# Reprocessing Image Number:  1247
# Reprocessing Image Number:  1248
# Reprocessing Image Number:  1249
# Reprocessing Image Number:  1250
# Reprocessing Image Number:  1251
# Reprocessing Image Number:  1252
# Reprocessing Image Number:  1253
# Reprocessing Image Number:  1254
# Reprocessing Image Number:  1255
# Reprocessing Image Number:  1256
# Reprocessing Image Number:  1257
# Reprocessing Image Number:  1258
# Reprocessing Image Number:  1259
# Reprocessing Image Number:  1260
# Reprocessing Image Number:  1261
# Reprocessing Image Number:  1262
# Reprocessing Image Number:  1263
# Reprocessing Image Number:  1264
# Reprocessing Image Number:  1265
# Reprocessing Image Number:  1266
# Reprocessing Image Number:  1267
# Reprocessing Image Number:  1268
# Reprocessing Image Number:  1269
# Reprocessing Image Number:  1270
# Reprocessing Image Number:  1271
# Reprocessing Image Number:  1272
# Reprocessing Image Number:  1273
# Reprocessing Image Number:  1274
# Reprocessing Image Number:  1275
# Reprocessing Image Number:  1276
# Reprocessing Image Number:  1277
# Reprocessing Image Number:  1278
# Reprocessing Image Number:  1279
# Reprocessing Image Number:  1280
# Reprocessing Image Number:  1281
# Reprocessing Image Number:  1282
# Reprocessing Image Number:  1283
# Reprocessing Image Number:  1284
# Reprocessing Image Number:  1285
# Reprocessing Image Number:  1286
# Reprocessing Image Number:  1287
# Reprocessing Image Number:  1288
# Reprocessing Image Number:  1289
# Reprocessing Image Number:  1290
# Reprocessing Image Number:  1291
# Reprocessing Image Number:  1292
# Reprocessing Image Number:  1293
# Reprocessing Image Number:  1294
# Reprocessing Image Number:  1295
# Reprocessing Image Number:  1296
# Reprocessing Image Number:  1297
# Reprocessing Image Number:  1298
# Reprocessing Image Number:  1299
# Reprocessing Image Number:  1300
# Reprocessing Image Number:  1301
# Reprocessing Image Number:  1302
# Reprocessing Image Number:  1303
# Reprocessing Image Number:  1304
# Reprocessing Image Number:  1305
# Reprocessing Image Number:  1306
# Reprocessing Image Number:  1307
# Reprocessing Image Number:  1308
# Reprocessing Image Number:  1309
# Reprocessing Image Number:  1310
# Reprocessing Image Number:  1311
# Reprocessing Image Number:  1312
# Reprocessing Image Number:  1313
# Reprocessing Image Number:  1314
# Reprocessing Image Number:  1315
# Reprocessing Image Number:  1316
# Reprocessing Image Number:  1317
# Reprocessing Image Number:  1318
# Reprocessing Image Number:  1319
# Reprocessing Image Number:  1320
# Reprocessing Image Number:  1321
# Reprocessing Image Number:  1322
# Reprocessing Image Number:  1323
# Reprocessing Image Number:  1324
# Reprocessing Image Number:  1325
# Reprocessing Image Number:  1326
# Reprocessing Image Number:  1327
# Reprocessing Image Number:  1328
# Reprocessing Image Number:  1329
# Reprocessing Image Number:  1330
# Reprocessing Image Number:  1331
# Reprocessing Image Number:  1332
# Reprocessing Image Number:  1333
# Reprocessing Image Number:  1334
# Reprocessing Image Number:  1335
# Reprocessing Image Number:  1336
# Reprocessing Image Number:  1337
# Reprocessing Image Number:  1338
# Reprocessing Image Number:  1339
# Reprocessing Image Number:  1340
# Reprocessing Image Number:  1341
# Reprocessing Image Number:  1342
# Reprocessing Image Number:  1343
# Reprocessing Image Number:  1344
# Reprocessing Image Number:  1345
# Reprocessing Image Number:  1346
# Reprocessing Image Number:  1347
# Reprocessing Image Number:  1348
# Reprocessing Image Number:  1349
# Reprocessing Image Number:  1350
# Reprocessing Image Number:  1351
# Reprocessing Image Number:  1352
# Reprocessing Image Number:  1353
# Reprocessing Image Number:  1354
# Reprocessing Image Number:  1355
# Reprocessing Image Number:  1356
# Reprocessing Image Number:  1357
# Reprocessing Image Number:  1358
# Reprocessing Image Number:  1359
# Reprocessing Image Number:  1360
# Reprocessing Image Number:  1361
# Reprocessing Image Number:  1362
# Reprocessing Image Number:  1363
# Reprocessing Image Number:  1364
# Reprocessing Image Number:  1365
# Reprocessing Image Number:  1366
# Reprocessing Image Number:  1367
# Reprocessing Image Number:  1368
# Reprocessing Image Number:  1369
# Reprocessing Image Number:  1370
# Reprocessing Image Number:  1371
# Reprocessing Image Number:  1372
# Reprocessing Image Number:  1373
# Reprocessing Image Number:  1374
# Reprocessing Image Number:  1375
# Reprocessing Image Number:  1376
# Reprocessing Image Number:  1377
# Reprocessing Image Number:  1378
# Reprocessing Image Number:  1379
# Reprocessing Image Number:  1380
# Reprocessing Image Number:  1381
# Reprocessing Image Number:  1382
# Reprocessing Image Number:  1383
# Reprocessing Image Number:  1384
# Reprocessing Image Number:  1385
# Reprocessing Image Number:  1386
# Reprocessing Image Number:  1387
# Reprocessing Image Number:  1388
# Reprocessing Image Number:  1389
# Reprocessing Image Number:  1390
# Reprocessing Image Number:  1391
# Reprocessing Image Number:  1392
# Reprocessing Image Number:  1393
# Reprocessing Image Number:  1394
# Reprocessing Image Number:  1395
# Reprocessing Image Number:  1396
# Reprocessing Image Number:  1397
# Reprocessing Image Number:  1398
# Reprocessing Image Number:  1399
# Reprocessing Image Number:  1400
# Reprocessing Image Number:  1401
# Reprocessing Image Number:  1402
# Reprocessing Image Number:  1403
# Reprocessing Image Number:  1404
# Reprocessing Image Number:  1405
# Reprocessing Image Number:  1406
# Reprocessing Image Number:  1407
# Reprocessing Image Number:  1408
# Reprocessing Image Number:  1409
# Reprocessing Image Number:  1410
# Reprocessing Image Number:  1411
# Reprocessing Image Number:  1412
# Reprocessing Image Number:  1413
# Reprocessing Image Number:  1414
# Reprocessing Image Number:  1415
# Reprocessing Image Number:  1416
# Reprocessing Image Number:  1417
# Reprocessing Image Number:  1418
# Reprocessing Image Number:  1419
# Reprocessing Image Number:  1420
# Reprocessing Image Number:  1421
# Reprocessing Image Number:  1422
# Reprocessing Image Number:  1423
# Reprocessing Image Number:  1424
# Reprocessing Image Number:  1425
# Reprocessing Image Number:  1426
# Reprocessing Image Number:  1427
# Reprocessing Image Number:  1428
# Reprocessing Image Number:  1429
# Reprocessing Image Number:  1430
# Reprocessing Image Number:  1431
# Reprocessing Image Number:  1432
# Reprocessing Image Number:  1433
# Reprocessing Image Number:  1434
# Reprocessing Image Number:  1435
# Reprocessing Image Number:  1436
# Reprocessing Image Number:  1437
# Reprocessing Image Number:  1438
# Reprocessing Image Number:  1439
# Reprocessing Image Number:  1440
# Reprocessing Image Number:  1441
# Reprocessing Image Number:  1442
# Reprocessing Image Number:  1443
# Reprocessing Image Number:  1444
# Reprocessing Image Number:  1445
# Reprocessing Image Number:  1446
# Reprocessing Image Number:  1447
# Reprocessing Image Number:  1448
# Reprocessing Image Number:  1449
# Reprocessing Image Number:  1450
# Reprocessing Image Number:  1451
# Reprocessing Image Number:  1452
# Reprocessing Image Number:  1453
# Reprocessing Image Number:  1454
# Reprocessing Image Number:  1455
# Reprocessing Image Number:  1456
# Reprocessing Image Number:  1457
# Reprocessing Image Number:  1458
# Reprocessing Image Number:  1459
# Reprocessing Image Number:  1460
# Reprocessing Image Number:  1461
# Reprocessing Image Number:  1462
# Reprocessing Image Number:  1463
# Reprocessing Image Number:  1464
# Reprocessing Image Number:  1465
# Reprocessing Image Number:  1466
# Reprocessing Image Number:  1467
# Reprocessing Image Number:  1468
# Reprocessing Image Number:  1469
# Reprocessing Image Number:  1470
# Reprocessing Image Number:  1471
# Reprocessing Image Number:  1472
# Reprocessing Image Number:  1473
# Reprocessing Image Number:  1474
# Reprocessing Image Number:  1475
# Reprocessing Image Number:  1476
# Reprocessing Image Number:  1477
# Reprocessing Image Number:  1478
# Reprocessing Image Number:  1479
# Reprocessing Image Number:  1480
# Reprocessing Image Number:  1481
# Reprocessing Image Number:  1482
# Reprocessing Image Number:  1483
# Reprocessing Image Number:  1484
# Reprocessing Image Number:  1485
# Reprocessing Image Number:  1486
# Reprocessing Image Number:  1487
# Reprocessing Image Number:  1488
# ...
# Reprocessing Image Number:  6425
# Reprocessing Image Number:  6426
# Reprocessing Image Number:  6427
# Reprocessing Image Number:  6428
# Reprocessing Image Number:  6429
# Reprocessing Image Number:  6430
# Reprocessing Image Number:  6431
# Reprocessing Image Number:  6432
# Reprocessing Image Number:  6433
# Reprocessing Image Number:  6434
# Reprocessing Image Number:  6435
# Reprocessing Image Number:  6436
# Reprocessing Image Number:  6437
# Reprocessing Image Number:  6438
# Reprocessing Image Number:  6439
# Reprocessing Image Number:  6440
# Reprocessing Image Number:  6441
# Reprocessing Image Number:  6442
# Reprocessing Image Number:  6443
# Reprocessing Image Number:  6444
# Reprocessing Image Number:  6445
# Reprocessing Image Number:  6446
# Reprocessing Image Number:  6447
# Reprocessing Image Number:  6448
# Reprocessing Image Number:  6449
# Reprocessing Image Number:  6450
# Reprocessing Image Number:  6451
# Reprocessing Image Number:  6452
# Reprocessing Image Number:  6453
# Reprocessing Image Number:  6454
# Reprocessing Image Number:  6455
# Reprocessing Image Number:  6456
# Reprocessing Image Number:  6457
# Reprocessing Image Number:  6458
# Reprocessing Image Number:  6459
# Reprocessing Image Number:  6460
# Reprocessing Image Number:  6461
# Reprocessing Image Number:  6462
# Reprocessing Image Number:  6463
# Reprocessing Image Number:  6464
# Reprocessing Image Number:  6465
# Reprocessing Image Number:  6466
# Reprocessing Image Number:  6467
# Reprocessing Image Number:  6468
# Reprocessing Image Number:  6469
# Reprocessing Image Number:  6470
# Reprocessing Image Number:  6471
# Reprocessing Image Number:  6472
# Reprocessing Image Number:  6473
# Reprocessing Image Number:  6474
# Reprocessing Image Number:  6475
# Reprocessing Image Number:  6476
# Reprocessing Image Number:  6477
# Reprocessing Image Number:  6478
# Reprocessing Image Number:  6479
# Reprocessing Image Number:  6480
# Reprocessing Image Number:  6481
# Reprocessing Image Number:  6482
# Reprocessing Image Number:  6483
# Reprocessing Image Number:  6484
# Reprocessing Image Number:  6485
# Reprocessing Image Number:  6486
# Reprocessing Image Number:  6487
# Reprocessing Image Number:  6488
# Reprocessing Image Number:  6489
# Reprocessing Image Number:  6490
# Reprocessing Image Number:  6491
# Reprocessing Image Number:  6492
# Reprocessing Image Number:  6493
# Reprocessing Image Number:  6494
# Reprocessing Image Number:  6495
# Reprocessing Image Number:  6496
# Reprocessing Image Number:  6497
# Reprocessing Image Number:  6498
# Reprocessing Image Number:  6499
# Reprocessing Image Number:  6500
# Reprocessing Image Number:  6501
# Reprocessing Image Number:  6502
# Reprocessing Image Number:  6503
# Reprocessing Image Number:  6504
# Reprocessing Image Number:  6505
# Reprocessing Image Number:  6506
# Reprocessing Image Number:  6507
# Reprocessing Image Number:  6508
# Reprocessing Image Number:  6509
# Reprocessing Image Number:  6510
# Reprocessing Image Number:  6511
# Reprocessing Image Number:  6512
# Reprocessing Image Number:  6513
# Reprocessing Image Number:  6514
# Reprocessing Image Number:  6515
# Reprocessing Image Number:  6516
# Reprocessing Image Number:  6517
# Reprocessing Image Number:  6518
# Reprocessing Image Number:  6519
# Reprocessing Image Number:  6520
# Reprocessing Image Number:  6521
# Reprocessing Image Number:  6522
# Reprocessing Image Number:  6523
# Reprocessing Image Number:  6524
# Reprocessing Image Number:  6525
# Reprocessing Image Number:  6526
# Reprocessing Image Number:  6527
# Reprocessing Image Number:  6528
# Reprocessing Image Number:  6529
# Reprocessing Image Number:  6530
# Reprocessing Image Number:  6531
# Reprocessing Image Number:  6532
# Reprocessing Image Number:  6533
# Reprocessing Image Number:  6534
# Reprocessing Image Number:  6535
# Reprocessing Image Number:  6536
# Reprocessing Image Number:  6537
# Reprocessing Image Number:  6538
# Reprocessing Image Number:  6539
# Reprocessing Image Number:  6540
# Reprocessing Image Number:  6541
# Reprocessing Image Number:  6542
# Reprocessing Image Number:  6543
# Reprocessing Image Number:  6544
# Reprocessing Image Number:  6545
# Reprocessing Image Number:  6546
# Reprocessing Image Number:  6547
# Reprocessing Image Number:  6548
# Reprocessing Image Number:  6549
# Reprocessing Image Number:  6550
# Reprocessing Image Number:  6551
# Reprocessing Image Number:  6552
# Reprocessing Image Number:  6553
# Reprocessing Image Number:  6554
# Reprocessing Image Number:  6555
# Reprocessing Image Number:  6556
# Reprocessing Image Number:  6557
# Reprocessing Image Number:  6558
# Reprocessing Image Number:  6559
# Reprocessing Image Number:  6560
# Reprocessing Image Number:  6561
# Reprocessing Image Number:  6562
# Reprocessing Image Number:  6563
# Reprocessing Image Number:  6564
# Reprocessing Image Number:  6565
# Reprocessing Image Number:  6566
# Reprocessing Image Number:  6567
# Reprocessing Image Number:  6568
# Reprocessing Image Number:  6569
# Reprocessing Image Number:  6570
# Reprocessing Image Number:  6571
# Reprocessing Image Number:  6572
# Reprocessing Image Number:  6573
# Reprocessing Image Number:  6574
# Reprocessing Image Number:  6575
# Reprocessing Image Number:  6576
# Reprocessing Image Number:  6577
# Reprocessing Image Number:  6578
# Reprocessing Image Number:  6579
# Reprocessing Image Number:  6580
# Reprocessing Image Number:  6581
# Reprocessing Image Number:  6582
# Reprocessing Image Number:  6583
# Reprocessing Image Number:  6584
# Reprocessing Image Number:  6585
# Reprocessing Image Number:  6586
# Reprocessing Image Number:  6587
# Reprocessing Image Number:  6588
# Reprocessing Image Number:  6589
# Reprocessing Image Number:  6590
# Reprocessing Image Number:  6591
# Reprocessing Image Number:  6592
# Reprocessing Image Number:  6593
# Reprocessing Image Number:  6594
# Reprocessing Image Number:  6595
# Reprocessing Image Number:  6596
# Reprocessing Image Number:  6597
# Reprocessing Image Number:  6598
# Reprocessing Image Number:  6599
# Reprocessing Image Number:  6600
# Reprocessing Image Number:  6601
# Reprocessing Image Number:  6602
# Reprocessing Image Number:  6603
# Reprocessing Image Number:  6604
# Reprocessing Image Number:  6605
# Reprocessing Image Number:  6606
# Reprocessing Image Number:  6607
# Reprocessing Image Number:  6608
# Reprocessing Image Number:  6609
# Reprocessing Image Number:  6610
# Reprocessing Image Number:  6611
# Reprocessing Image Number:  6612
# Reprocessing Image Number:  6613
# Reprocessing Image Number:  6614
# Reprocessing Image Number:  6615
# Reprocessing Image Number:  6616
# Reprocessing Image Number:  6617
# Reprocessing Image Number:  6618
# Reprocessing Image Number:  6619
# Reprocessing Image Number:  6620
# Reprocessing Image Number:  6621
# Reprocessing Image Number:  6622
# Reprocessing Image Number:  6623
# Reprocessing Image Number:  6624
# Reprocessing Image Number:  6625
# Reprocessing Image Number:  6626
# Reprocessing Image Number:  6627
# Reprocessing Image Number:  6628
# Reprocessing Image Number:  6629
# Reprocessing Image Number:  6630
# Reprocessing Image Number:  6631
# Reprocessing Image Number:  6632
# Reprocessing Image Number:  6633
# Reprocessing Image Number:  6634
# Reprocessing Image Number:  6635
# Reprocessing Image Number:  6636
# Reprocessing Image Number:  6637
# Reprocessing Image Number:  6638
# Reprocessing Image Number:  6639
# Reprocessing Image Number:  6640
# Reprocessing Image Number:  6641
# Reprocessing Image Number:  6642
# Reprocessing Image Number:  6643
# Reprocessing Image Number:  6644
# Reprocessing Image Number:  6645
# Reprocessing Image Number:  6646
# Reprocessing Image Number:  6647
# Reprocessing Image Number:  6648
# Reprocessing Image Number:  6649
# Reprocessing Image Number:  6650
# Reprocessing Image Number:  6651
# Reprocessing Image Number:  6652
# Reprocessing Image Number:  6653
# Reprocessing Image Number:  6654
# Reprocessing Image Number:  6655
# Reprocessing Image Number:  6656
# Reprocessing Image Number:  6657
# Reprocessing Image Number:  6658
# Reprocessing Image Number:  6659
# Reprocessing Image Number:  6660
# Reprocessing Image Number:  6661
# Reprocessing Image Number:  6662
# Reprocessing Image Number:  6663
# Reprocessing Image Number:  6664
# Reprocessing Image Number:  6665
# Reprocessing Image Number:  6666
# Reprocessing Image Number:  6667
# Reprocessing Image Number:  6668
# Reprocessing Image Number:  6669
# Reprocessing Image Number:  6670
# Reprocessing Image Number:  6671
# Reprocessing Image Number:  6672
# Reprocessing Image Number:  6673
# Reprocessing Image Number:  6674
# Reprocessing Image Number:  6675
# Reprocessing Image Number:  6676
# Reprocessing Image Number:  6677
# Reprocessing Image Number:  6678
# Reprocessing Image Number:  6679
# Reprocessing Image Number:  6680
# Reprocessing Image Number:  6681
# Reprocessing Image Number:  6682
# Reprocessing Image Number:  6683
# Reprocessing Image Number:  6684
# Reprocessing Image Number:  6685
# Reprocessing Image Number:  6686
# Reprocessing Image Number:  6687
# Reprocessing Image Number:  6688
# Reprocessing Image Number:  6689
# Reprocessing Image Number:  6690
# Reprocessing Image Number:  6691
# Reprocessing Image Number:  6692
# Reprocessing Image Number:  6693
# Reprocessing Image Number:  6694
# Reprocessing Image Number:  6695
# Reprocessing Image Number:  6696
# Reprocessing Image Number:  6697
# Reprocessing Image Number:  6698
# Reprocessing Image Number:  6699
# Reprocessing Image Number:  6700
# Reprocessing Image Number:  6701
# Reprocessing Image Number:  6702
# Reprocessing Image Number:  6703
# Reprocessing Image Number:  6704
# Reprocessing Image Number:  6705
# Reprocessing Image Number:  6706
# Reprocessing Image Number:  6707
# Reprocessing Image Number:  6708
# Reprocessing Image Number:  6709
# Reprocessing Image Number:  6710
# Reprocessing Image Number:  6711
# Reprocessing Image Number:  6712
# Reprocessing Image Number:  6713
# Reprocessing Image Number:  6714
# Reprocessing Image Number:  6715
# Reprocessing Image Number:  6716
# Reprocessing Image Number:  6717
# Reprocessing Image Number:  6718
# Reprocessing Image Number:  6719
# Reprocessing Image Number:  6720
# Reprocessing Image Number:  6721
# Reprocessing Image Number:  6722
# Reprocessing Image Number:  6723
# Reprocessing Image Number:  6724
# Reprocessing Image Number:  6725
# Reprocessing Image Number:  6726
# Reprocessing Image Number:  6727
# Reprocessing Image Number:  6728
# Reprocessing Image Number:  6729
# Reprocessing Image Number:  6730
# Reprocessing Image Number:  6731
# Reprocessing Image Number:  6732
# Reprocessing Image Number:  6733
# Reprocessing Image Number:  6734
# Reprocessing Image Number:  6735
# Reprocessing Image Number:  6736
# Reprocessing Image Number:  6737
# Reprocessing Image Number:  6738
# Reprocessing Image Number:  6739
# Reprocessing Image Number:  6740
# Reprocessing Image Number:  6741
# Reprocessing Image Number:  6742
# Reprocessing Image Number:  6743
# Reprocessing Image Number:  6744
# Reprocessing Image Number:  6745
# Reprocessing Image Number:  6746
# Reprocessing Image Number:  6747
# Reprocessing Image Number:  6748
# Reprocessing Image Number:  6749
# Reprocessing Image Number:  6750
# Reprocessing Image Number:  6751
# Reprocessing Image Number:  6752
# Reprocessing Image Number:  6753
# Reprocessing Image Number:  6754
# Reprocessing Image Number:  6755
# Reprocessing Image Number:  6756
# Reprocessing Image Number:  6757
# Reprocessing Image Number:  6758
# Reprocessing Image Number:  6759
# Reprocessing Image Number:  6760
# Reprocessing Image Number:  6761
# Reprocessing Image Number:  6762
# Reprocessing Image Number:  6763
# Reprocessing Image Number:  6764
# Reprocessing Image Number:  6765
# Reprocessing Image Number:  6766
# Reprocessing Image Number:  6767
# Reprocessing Image Number:  6768
# Reprocessing Image Number:  6769
# Reprocessing Image Number:  6770
# Reprocessing Image Number:  6771
# Reprocessing Image Number:  6772
# Reprocessing Image Number:  6773
# Reprocessing Image Number:  6774
# Reprocessing Image Number:  6775
# Reprocessing Image Number:  6776
# Reprocessing Image Number:  6777
# Reprocessing Image Number:  6778
# Reprocessing Image Number:  6779
# Reprocessing Image Number:  6780
# Reprocessing Image Number:  6781
# Reprocessing Image Number:  6782
# Reprocessing Image Number:  6783
# Reprocessing Image Number:  6784
# Reprocessing Image Number:  6785
# Reprocessing Image Number:  6786
# Reprocessing Image Number:  6787
# Reprocessing Image Number:  6788
# Reprocessing Image Number:  6789
# Reprocessing Image Number:  6790
# Reprocessing Image Number:  6791
# Reprocessing Image Number:  6792
# Reprocessing Image Number:  6793
# Reprocessing Image Number:  6794
# Reprocessing Image Number:  6795
# Reprocessing Image Number:  6796
# Reprocessing Image Number:  6797
# Reprocessing Image Number:  6798
# Reprocessing Image Number:  6799
# Reprocessing Image Number:  6800
# Reprocessing Image Number:  6801
# Reprocessing Image Number:  6802
# Reprocessing Image Number:  6803
# Reprocessing Image Number:  6804
# Reprocessing Image Number:  6805
# Reprocessing Image Number:  6806
# Reprocessing Image Number:  6807
# Reprocessing Image Number:  6808
# Reprocessing Image Number:  6809
# Reprocessing Image Number:  6810
# Reprocessing Image Number:  6811
# Reprocessing Image Number:  6812
# Reprocessing Image Number:  6813
# Reprocessing Image Number:  6814
# Reprocessing Image Number:  6815
# Reprocessing Image Number:  6816
# Reprocessing Image Number:  6817
# Reprocessing Image Number:  6818
# Reprocessing Image Number:  6819
# Reprocessing Image Number:  6820
# Reprocessing Image Number:  6821
# Reprocessing Image Number:  6822
# Reprocessing Image Number:  6823
# Reprocessing Image Number:  6824
# Reprocessing Image Number:  6825
# Reprocessing Image Number:  6826
# Reprocessing Image Number:  6827
# Reprocessing Image Number:  6828
# Reprocessing Image Number:  6829
# Reprocessing Image Number:  6830
# Reprocessing Image Number:  6831
# Reprocessing Image Number:  6832
# Reprocessing Image Number:  6833
# Reprocessing Image Number:  6834
# Reprocessing Image Number:  6835
# Reprocessing Image Number:  6836
# Reprocessing Image Number:  6837
# Reprocessing Image Number:  6838
# Reprocessing Image Number:  6839
# Reprocessing Image Number:  6840
# Reprocessing Image Number:  6841
# Reprocessing Image Number:  6842
# Reprocessing Image Number:  6843
# Reprocessing Image Number:  6844
# Reprocessing Image Number:  6845
# Reprocessing Image Number:  6846
# Reprocessing Image Number:  6847
# Reprocessing Image Number:  6848
# Reprocessing Image Number:  6849
# Reprocessing Image Number:  6850
# Reprocessing Image Number:  6851
# Reprocessing Image Number:  6852
# Reprocessing Image Number:  6853
# Reprocessing Image Number:  6854
# Reprocessing Image Number:  6855
# Reprocessing Image Number:  6856
# Reprocessing Image Number:  6857
# Reprocessing Image Number:  6858
# Reprocessing Image Number:  6859
# Reprocessing Image Number:  6860
# Reprocessing Image Number:  6861
# Reprocessing Image Number:  6862
# Reprocessing Image Number:  6863
# Reprocessing Image Number:  6864
# Reprocessing Image Number:  6865
# Reprocessing Image Number:  6866
# Reprocessing Image Number:  6867
# Reprocessing Image Number:  6868
# Reprocessing Image Number:  6869
# Reprocessing Image Number:  6870
# Reprocessing Image Number:  6871
# Reprocessing Image Number:  6872
# Reprocessing Image Number:  6873
# Reprocessing Image Number:  6874
# Reprocessing Image Number:  6875
# Reprocessing Image Number:  6876
# Reprocessing Image Number:  6877
# Reprocessing Image Number:  6878
# Reprocessing Image Number:  6879
# Reprocessing Image Number:  6880
# Reprocessing Image Number:  6881
# Reprocessing Image Number:  6882
# Reprocessing Image Number:  6883
# Reprocessing Image Number:  6884
# Reprocessing Image Number:  6885
# Reprocessing Image Number:  6886
# Reprocessing Image Number:  6887
# Reprocessing Image Number:  6888
# Reprocessing Image Number:  6889
# Reprocessing Image Number:  6890
# Reprocessing Image Number:  6891
# Reprocessing Image Number:  6892
# Reprocessing Image Number:  6893
# Reprocessing Image Number:  6894
# Reprocessing Image Number:  6895
# Reprocessing Image Number:  6896
# Reprocessing Image Number:  6897
# Reprocessing Image Number:  6898
# Reprocessing Image Number:  6899
# Reprocessing Image Number:  6900
# Reprocessing Image Number:  6901
# Reprocessing Image Number:  6902
# Reprocessing Image Number:  6903
# Reprocessing Image Number:  6904
# Reprocessing Image Number:  6905
# Reprocessing Image Number:  6906
# Reprocessing Image Number:  6907
# Reprocessing Image Number:  6908

# %%
#Label Encoding
le = preprocessing.LabelEncoder()
le.fit(lbls)
lbls_encoded = le.transform(lbls)
#Train and Test Split
train_x, test_x,train_y, test_y = train_test_split(imgs,lbls_encoded,test_size=0.1)
 
#Normalization
train_x, test_x = train_x / 255.0,  test_x / 255.0

# %%
print(lbls)
print(lbls_encoded)
# Out:
# ['Cars' 'Cars' 'Cars' ... 'Women' 'Women' 'Women']
# [0 0 0 ... 6 6 6]

# %%
VGG_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_size,img_size, 3))
 
for layer in VGG_model.layers:
	layer.trainable = False   # overfit ll ACCURACY
 
VGG_model.summary()  
feature_extractor=VGG_model.predict(train_x)
features = feature_extractor.reshape(feature_extractor.shape[0], -1)

X_for_RF = features

feature_extractor_test=VGG_model.predict(test_x)
features_test = feature_extractor_test.reshape(feature_extractor_test.shape[0], -1)
model = keras.models.Sequential([
    keras.layers.Flatten(),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")])

model.compile(loss="sparse_categorical_crossentropy",optimizer="sgd",metrics=["accuracy"])

ann=model.fit(X_for_RF, train_y, epochs=30,validation_data=(features_test, test_y))

y_preds = model.predict(features_test).argmax(axis=1)

Accuracy = accuracy_score(test_y,y_preds)

print("Accuracy :", Accuracy)
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# 195/195 [==============================] - 1109s 6s/step
# 22/22 [==============================] - 122s 6s/step
# Epoch 1/30
# 195/195 [==============================] - 9s 39ms/step - loss: 1.0631 - accuracy: 0.6217 - val_loss: 0.6886 - val_accuracy: 0.7800
# Epoch 2/30
# 195/195 [==============================] - 7s 36ms/step - loss: 0.3697 - accuracy: 0.8488 - val_loss: 0.7120 - val_accuracy: 0.7062
# Epoch 3/30
# 195/195 [==============================] - 7s 37ms/step - loss: 0.2669 - accuracy: 0.8909 - val_loss: 0.5834 - val_accuracy: 0.7554
# Epoch 4/30
# 195/195 [==============================] - 8s 39ms/step - loss: 0.2271 - accuracy: 0.9133 - val_loss: 0.3537 - val_accuracy: 0.8755
# Epoch 5/30
# 195/195 [==============================] - 8s 39ms/step - loss: 0.1922 - accuracy: 0.9273 - val_loss: 0.2754 - val_accuracy: 0.8770
# Epoch 6/30
# 195/195 [==============================] - 8s 38ms/step - loss: 0.1612 - accuracy: 0.9352 - val_loss: 0.1754 - val_accuracy: 0.9378
# Epoch 7/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.1508 - accuracy: 0.9411 - val_loss: 0.6811 - val_accuracy: 0.8090
# Epoch 8/30
# 195/195 [==============================] - 7s 36ms/step - loss: 0.1292 - accuracy: 0.9537 - val_loss: 0.1851 - val_accuracy: 0.9291
# Epoch 9/30
# 195/195 [==============================] - 7s 37ms/step - loss: 0.1248 - accuracy: 0.9535 - val_loss: 0.1689 - val_accuracy: 0.9291
# Epoch 10/30
# 195/195 [==============================] - 8s 39ms/step - loss: 0.1070 - accuracy: 0.9604 - val_loss: 0.1497 - val_accuracy: 0.9436
# Epoch 11/30
# 195/195 [==============================] - 7s 37ms/step - loss: 0.0999 - accuracy: 0.9619 - val_loss: 0.3659 - val_accuracy: 0.8640
# Epoch 12/30
# 195/195 [==============================] - 7s 37ms/step - loss: 0.0877 - accuracy: 0.9672 - val_loss: 0.5723 - val_accuracy: 0.7945
# Epoch 13/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.0920 - accuracy: 0.9656 - val_loss: 0.4377 - val_accuracy: 0.8582
# Epoch 14/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.0779 - accuracy: 0.9699 - val_loss: 0.4012 - val_accuracy: 0.8640
# Epoch 15/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.0754 - accuracy: 0.9725 - val_loss: 0.1816 - val_accuracy: 0.9305
# Epoch 16/30
# 195/195 [==============================] - 7s 37ms/step - loss: 0.0682 - accuracy: 0.9764 - val_loss: 0.1707 - val_accuracy: 0.9276
# Epoch 17/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.0614 - accuracy: 0.9760 - val_loss: 0.1464 - val_accuracy: 0.9392
# Epoch 18/30
# 195/195 [==============================] - 7s 37ms/step - loss: 0.0499 - accuracy: 0.9828 - val_loss: 0.1696 - val_accuracy: 0.9349
# Epoch 19/30
# 195/195 [==============================] - 7s 37ms/step - loss: 0.0566 - accuracy: 0.9810 - val_loss: 0.1822 - val_accuracy: 0.9320
# Epoch 20/30
# 195/195 [==============================] - 7s 37ms/step - loss: 0.0459 - accuracy: 0.9849 - val_loss: 0.1849 - val_accuracy: 0.9363
# Epoch 21/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.0441 - accuracy: 0.9866 - val_loss: 0.1598 - val_accuracy: 0.9320
# Epoch 22/30
# 195/195 [==============================] - 9s 46ms/step - loss: 0.0540 - accuracy: 0.9833 - val_loss: 0.1509 - val_accuracy: 0.9421
# Epoch 23/30
# 195/195 [==============================] - 8s 38ms/step - loss: 0.0392 - accuracy: 0.9870 - val_loss: 0.1747 - val_accuracy: 0.9320
# Epoch 24/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.0340 - accuracy: 0.9883 - val_loss: 0.1705 - val_accuracy: 0.9334
# Epoch 25/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.1670 - accuracy: 0.9608 - val_loss: 0.4454 - val_accuracy: 0.8321
# Epoch 26/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.1481 - accuracy: 0.9580 - val_loss: 0.3107 - val_accuracy: 0.8958
# Epoch 27/30
# 195/195 [==============================] - 8s 42ms/step - loss: 0.0936 - accuracy: 0.9710 - val_loss: 0.1779 - val_accuracy: 0.9349
# Epoch 28/30
# 195/195 [==============================] - 7s 36ms/step - loss: 0.0544 - accuracy: 0.9833 - val_loss: 0.6402 - val_accuracy: 0.8133
# Epoch 29/30
# 195/195 [==============================] - 7s 38ms/step - loss: 0.3038 - accuracy: 0.9323 - val_loss: 0.5294 - val_accuracy: 0.8177
# Epoch 30/30
# 195/195 [==============================] - 7s 37ms/step - loss: 0.1211 - accuracy: 0.9625 - val_loss: 0.2344 - val_accuracy: 0.9175
# 22/22 [==============================] - 0s 9ms/step
# Accuracy : 0.9175108538350217

# %%
print("Loss Curve :")
plt.plot(ann.history['loss'])
plt.plot(ann.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()
# Out:
# Loss Curve :

# %%
cm = confusion_matrix(test_y, y_preds)
print("Confusion Matrix :")
print(cm)
# Out:
# Confusion Matrix :
# [[100   0   0   0   0   0   0]
#  [  0  96   1   0   1   0   0]
#  [  0   1 114   0   1   0   0]
#  [  0   1   4  82   3   0   0]
#  [  0   2   1   0  97   0   4]
#  [  0   0   1   0   0  87   0]
#  [  0   2   0   0  35   0  58]]

# %%
n_classes=5;
test_y2 = label_binarize(test_y, classes=[0,1,2,3,4,5])
pred2 = label_binarize(y_preds, classes=[0,1,2,3,4,5])
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(5):
    fpr[i], tpr[i], _ = roc_curve(test_y2[:, i], pred2[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Plot of a ROC curve for a specific class
for i in range(5):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %%
from tkinter import *
import tkinter as tk
from tkinter import filedialog
from tkinter.filedialog import askopenfile
from PIL import Image, ImageTk
 
Main = tk.Tk()
Main.geometry("600x600")  # Size of the window 
Main.resizable(width=False, height=False)
Main.title('Object Detection')
Main['background']='#21374d' 
my_font1=('times', 25, 'bold')
my_font2=('times', 16, 'bold')
label = tk.Label(Main,text='Upload Image',width=30,font=my_font1)
label.grid(row=1,column=1,pady=100,padx=100)
label['background']='#2074b0' 
label.place(anchor = CENTER, relx = .5, rely = .025)
 
 
b1 = tk.Button(Main, text='Upload Images', width=20,command = lambda:upload_file())
b1.grid(row=2,column=1,pady=5)
b1.place(anchor = CENTER, relx = .5, rely = .095)

def upload_file():
    f_types = [('Jpg Files', '*.jpg'),
    ('PNG Files','*.png'),('Jpeg Files', '*.jpeg')]   # types of files to select 
    filename = tk.filedialog.askopenfilename(multiple=True,filetypes=f_types)

    col=1 # start from column 1
    row=3 # start from row 3 
    for pathgui in filename:
        img=Image.open(pathgui)# read the image file
        list_of_images = []
        img_preprocessed = cv2.imread(pathgui, cv2.IMREAD_COLOR)
        img_preprocessed = cv2.resize(img_preprocessed, (img_size,img_size))
        img_preprocessed = cv2.cvtColor(img_preprocessed, cv2.COLOR_RGB2BGR)
        list_of_images.append(img_preprocessed)
        
        arr = np.array(list_of_images)
        
        feature_extractor_test=VGG_model.predict(arr)
        
        features_test = feature_extractor_test.reshape(feature_extractor_test.shape[0], -1)
        
        Ann_input = model.predict(features_test).argmax(axis=1)

        Ann_input_Normal = le.inverse_transform(Ann_input)

        img=img.resize((144,144)) 
        img=ImageTk.PhotoImage(img)
        e1 =tk.Label(Main)
        e1.grid(row=row,column=col,pady=100,padx=10)
        e1.image = img
        e1.place(anchor = CENTER, relx = .5, rely = .355)
        text_answer=Ann_input_Normal
        text_answer=text_answer.tolist()
        l2 = tk.Label(Main,text=text_answer,width=30,font=my_font2)  
        l2.grid(row=row+1,column=col,pady=0,padx=10)
        l2.place(anchor = CENTER, relx = .5, rely = .555)
        l2['background']='#fff'
        e1['image']=img # garbage collection
        if(col==7):
            row=row+2
            col=1    
        else:      
            col=col+1  
Main.mainloop()
# Out:
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 23ms/step
